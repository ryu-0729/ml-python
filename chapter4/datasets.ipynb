# %% [markdown]
# <a href="https://colab.research.google.com/github/ryu-0729/ml-python/blob/master/chapter4/datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TFDS入門
# Fashion MNISTの利用

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

print(tfds.__version__)
# Out:
# 4.8.3

# %% [markdown]
# ### データセットの取得

# %%
mnist_data = tfds.load('fashion_mnist')
for item in mnist_data:
    print(item)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/fashion_mnist/3.0.1.incompleteIY6SJB/fashion_mnist-train.tfrecord*...:   0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/fashion_mnist/3.0.1.incompleteIY6SJB/fashion_mnist-test.tfrecord*...:   0%…
# Dataset fashion_mnist downloaded and prepared to /root/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# train
# test

# %% [markdown]
# ## TFDSによるKerasモデルの使用方法

# %%
(training_images, training_labels), (test_images, test_labels) = tfds.as_numpy(tfds.load(
    'fashion_mnist',
    split = ['train', 'test'],
    batch_size=-1,
    as_supervised=True,
))

training_images = training_images / 255.0
test_images = test_images / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(training_images, training_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 3ms/step - loss: 0.5307 - accuracy: 0.8133
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3982 - accuracy: 0.8555
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3685 - accuracy: 0.8647
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3474 - accuracy: 0.8713
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3306 - accuracy: 0.8768
